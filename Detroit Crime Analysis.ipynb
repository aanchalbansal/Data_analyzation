# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # SAMPLE DATA FOR CRIME IN DETROIT

# %%
df=pd.read_csv("/Users/Aanchal/Documents/detroit-crimeincidents20092016/DPD__All_Crime_Incidents__January_1__2009_-_December_6__2016.csv")
df.head()
# Out:
# C:\Users\Aanchal\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2714: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    ROWNUM   CASEID  CRIMEID          CRNO       CATEGORY  \
# 0       1  1099487  1321797  0910020373.1  MISCELLANEOUS
# 1       2  1117507  1344185  0911060289.1  MISCELLANEOUS
# 2       3   985415  1181882  0902190512.1  MISCELLANEOUS
# 3       4   986019  1182632  0902200294.1  MISCELLANEOUS
# 4       5   996883  1195867  0903170149.1        LARCENY
#
#                                   OFFENSEDESCRIPTION  STATEOFFENSEFILECLASS  \
# 0               MISCELLANEOUS - GENERAL NON-CRIMINAL                99009.0
# 1               MISCELLANEOUS - GENERAL NON-CRIMINAL                99009.0
# 2                  MISCELLANEOUS - ABANDONED VEHICLE                99009.0
# 3               MISCELLANEOUS - GENERAL NON-CRIMINAL                99009.0
# 4  LARCENY - FROM BUILDING (INCLUDES LIBRARY, OFF...                23003.0
#
#              INCIDENTDATE  HOUR     SCA  PRECINCT                  COUNCIL  \
# 0  01/01/2009 12:00:00 AM     0  1107.0      11.0  City Council District 3
# 1  01/01/2009 12:00:00 AM     0     NaN       NaN                      NaN
# 2  01/01/2009 12:00:00 AM     0  1005.0      10.0  City Council District 5
# 3  01/01/2009 12:00:00 AM     0   414.0       4.0  City Council District 6
# 4  01/01/2009 12:00:00 AM     0   908.0       9.0  City Council District 3
#
#       NEIGHBORHOOD  CENSUSTRACT  \
# 0   CONANT GARDENS       5070.0
# 1              NaN    9999999.0
# 2             PECK       5313.0
# 3  HUBBARD-RICHARD       5211.0
# 4          BURBANK       5052.0
#
#                                          LOCATION
# 0              18000 WEXFORD\n(42.4261, -83.0649)
# 1               00 UNKNOWN\n(999999, 999999.0001)
# 2              02000 CALVERT\n(42.3821, -83.1058)
# 3  00 W GRAND BLVD AND W FORT\n(42.3145, -83.083)
# 4                12500 CONNER\n(42.4134, -83.008)

# %% [markdown]
# # CRIMES vs FREQUENCY

# %%
plt.figure(figsize=(15,15))
df.CATEGORY.value_counts().plot('bar')
plt.xlabel('Type of crime')
plt.ylabel('frequency')
# Out:
# Text(0,0.5,'frequency')

# %% [markdown]
# # NEIGHBOUHOOD-WISE CRIMES vs FREQUENCY

# %%
plt.figure(figsize=(30,30))
df.NEIGHBORHOOD.value_counts().plot('bar')
plt.xlabel('Neighbourhood where crime took place')
plt.ylabel('frequency')
# Out:
# Text(0,0.5,'frequency')

# %% [markdown]
# # DISTRICT-WISE CRIMES vs FREQUENCY

# %%
df.COUNCIL.value_counts().plot('bar')
plt.xlabel('Crime in District')
plt.ylabel('Frequency')
# Out:
# Text(0,0.5,'Frequency')

# %% [markdown]
# # DISTRICT-WISE DISTRIBUTION OF DATA WITH FREQUENCY OF EACH CRIME

# %%
for i in list(df.COUNCIL.unique()):
    if pd.isnull(i):
        continue
    fig=plt.figure()
    df[df.COUNCIL==i].CATEGORY.value_counts().plot.bar()
    plt.title(i)
    plt.xlabel('Crimes')
    plt.ylabel('Frequency')

# %% [markdown]
# # CRIME-WISE DISTRIBUTION OF DATA WITH FREQUENCY OF THAT CRIME IN EACH COUNCIL

# %%
#print(type(df[df.CATEGORY==i].COUNCIL.value_counts()))
for i in list(df.CATEGORY.unique()):
    if i=='SEX OFFENSES':
        continue
    fig=plt.figure()
    df[df.CATEGORY==i].COUNCIL.value_counts().plot.bar()
    plt.title(i)
    plt.xlabel('COUNCIL')
    plt.ylabel('Frequency')
# Out:
# C:\Users\Aanchal\Anaconda2\lib\site-packages\matplotlib\pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
import datetime

# %% [markdown]
# # HOUR-WISE DISTRIBUTION OF DATA WITH FREQUENCY OF EACH CRIME

# %%
for i in df.HOUR.sort_values().unique():
    fig=plt.figure()
    df[df.HOUR==i].CATEGORY.value_counts().plot.bar()
    plt.title(('{} HOUR').format(i))
    plt.xlabel('CATEGORY')
    plt.ylabel('Frequency')

# %% [markdown]
# # CRIME-WISE DISTRIBUTION OF DATA WITH FREQUENCY OF CRIMES IN DIFFERENT HOURS

# %%
for i in df.CATEGORY.unique():
    fig=plt.figure()
    tmp=df[df.CATEGORY==i].HOUR.value_counts()#.plot.bar()
    tmp.sort_index().plot.bar()
    plt.xlabel('HOUR')
    plt.title(i)
    plt.ylabel('Frequency')

# %%
#df['DATE'],df['Time']=
#x=df['INCIDENTDATE'].str.split(" ",expand=True)
#df['DATE']=x[0]
#df.DATE.value_counts().plot()
